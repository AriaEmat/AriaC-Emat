# %% [markdown]
# # System Check

# %% [markdown]
# ## *What i hope to learn*

# %% [markdown]
# 1. **what this program even does**
# 2. how this program even works
# 3. more skills that i can apply towards the job search

# %% [markdown]
# ![rat.png](attachment:16a35840-1994-4744-a59e-6b15d53dfb7c.png)
